# %% [markdown]
# <a href="https://colab.research.google.com/github/tanupriya9102/NLP-and-ML/blob/main/ML1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('smsspamcollection.tsv',sep='\t')

# %%
df.head()
# Out:
#   label                                            message  length  punct
# 0   ham  Go until jurong point, crazy.. Available only ...     111      9
# 1   ham                      Ok lar... Joking wif u oni...      29      6
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...     155      6
# 3   ham  U dun say so early hor... U c already then say...      49      6
# 4   ham  Nah I don't think he goes to usf, he lives aro...      61      2

# %%
df.isnull().sum() #returns the number of null values in each column
# Out:
# label      0
# message    0
# length     0
# punct      0
# dtype: int64

# %%
df1=pd.read_csv('newspam.txt',sep='\t')

# %%
df1.head()
# Out:
#   label                                            message  length  punct
# 0   ham  Go until jurong point, crazy.. Available only ...     111    9.0
# 1   ham                      Ok lar... Joking wif u oni...      29    6.0
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...     155    6.0
# 3   ham  U dun say so early hor... U c already then say...      49    NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...      61    2.0

# %%
df1.isnull().sum() #returns the number of null values in each column
# Out:
# label      0
# message    0
# length     0
# punct      3
# dtype: int64

# %%
# To get the row of data where value is null
NullVal=pd.isnull(df1['punct'])
df1[NullVal]
# Out:
#    label                                            message  length  punct
# 3    ham  U dun say so early hor... U c already then say...      49    NaN
# 16   ham                         Oh k...i'm watching here:)      26    NaN
# 20   ham          Is that seriously how you spell his name?      41    NaN

# %%
len(df)
# Out:
# 5572

# %%
df['label'].unique()
# Out:
# array(['ham', 'spam'], dtype=object)

# %%
df['label'].value_counts()
# Out:
# ham     4825
# spam     747
# Name: label, dtype: int64
